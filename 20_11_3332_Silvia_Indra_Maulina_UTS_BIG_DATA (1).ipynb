# %% [markdown]
# # UJIAN TENGAH SEMESTER
# # SILVIA INDRA MAULINA 20.11.3332
# #  Dataset = https://www.kaggle.com/datasets/sayansh001/speech-accent-recognition

# %%
import pandas as pd
train_df = pd.read_csv('train.csv')

# %%
train_df.head()
# Out:
#           X1        X2        X3         X4        X5         X6         X7  \
# 0   8.118459 -2.784780  0.414908   0.907955 -7.995316  15.525385 -10.439900
# 1  -2.374189 -7.297245  7.349022   7.524122 -7.129271  11.292515 -13.649587
# 2  -0.791621  1.303788 -1.791229   6.227355 -9.602931   8.602848  -7.727415
# 3  -3.177167 -4.239308  1.106003  10.937736 -8.870120   6.314209  -9.932148
# 4  10.978152  1.643641  6.195087   1.265713  5.735026   9.046351  -7.799853
#
#          X8        X9       X10       X11       X12 language
# 0  5.001569 -1.512281 -2.719342  2.222301 -5.846886       US
# 1  4.615975 -0.784158 -4.178449  1.320741  2.530421       ES
# 2  6.436677 -0.055187  0.486530  1.698110 -1.761528       FR
# 3  0.379124 -1.273991 -0.336232  5.219751 -5.748222       US
# 4  0.789758 -2.697877 -9.736504  4.329233 -4.248319       UK

# %%
train_df.shape
# Out:
# (3960, 13)

# %%
train_df.columns
# Out:
# Index(['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11',
#        'X12', 'language'],
#       dtype='object')

# %%
train_df.dtypes
# Out:
# X1          float64
# X2          float64
# X3          float64
# X4          float64
# X5          float64
# X6          float64
# X7          float64
# X8          float64
# X9          float64
# X10         float64
# X11         float64
# X12         float64
# language     object
# dtype: object

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3960 entries, 0 to 3959
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   X1        3960 non-null   float64
#  1   X2        3960 non-null   float64
#  2   X3        3960 non-null   float64
#  3   X4        3960 non-null   float64
#  4   X5        3960 non-null   float64
#  5   X6        3960 non-null   float64
#  6   X7        3960 non-null   float64
#  7   X8        3960 non-null   float64
#  8   X9        3960 non-null   float64
#  9   X10       3960 non-null   float64
#  10  X11       3960 non-null   float64
#  11  X12       3960 non-null   float64
#  12  language  3960 non-null   object
# dtypes: float64(12), object(1)
# memory usage: 402.3+ KB

# %%
train_df.isna().values.any()
# Out:
# False

# %%
train_df.isna().sum()
# Out:
# X1          0
# X2          0
# X3          0
# X4          0
# X5          0
# X6          0
# X7          0
# X8          0
# X9          0
# X10         0
# X11         0
# X12         0
# language    0
# dtype: int64

# %%
train_df[train_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [X1, X2, X3, X4, X5, X6, X7, X8, X9, X10, X11, X12, language]
# Index: []

# %%
train_df.duplicated()
train_df.shape
# Out:
# (3960, 13)

# %%
train_df.describe()
# Out:
#                 X1           X2           X3           X4           X5  \
# count  3960.000000  3960.000000  3960.000000  3960.000000  3960.000000
# mean      7.118650    -5.629135     2.212152     6.483972    -5.047163
# std       6.680266     4.964840     3.408380     4.821019     4.700817
# min      -4.835242   -14.972962    -6.186583    -8.844231   -14.637559
# 25%       1.589922   -11.581520     0.058247     2.550606    -8.120223
# 50%       6.525167    -5.305916     1.569968     6.493896    -6.289175
# 75%      14.964859    -1.153177     3.861871     9.838585    -2.288359
# max      17.749851     3.570765    17.066487    16.178942     7.912809
#
#                 X6           X7           X8           X9          X10  \
# count  3960.000000  3960.000000  3960.000000  3960.000000  3960.000000
# mean      9.404835    -9.272039     4.845774    -0.620685    -3.331677
# std       5.002050     3.438432     2.739237     2.925264     3.744268
# ...

# %%
train_df.describe()
# Out:
#                 X1           X2           X3           X4           X5  \
# count  3960.000000  3960.000000  3960.000000  3960.000000  3960.000000
# mean      7.118650    -5.629135     2.212152     6.483972    -5.047163
# std       6.680266     4.964840     3.408380     4.821019     4.700817
# min      -4.835242   -14.972962    -6.186583    -8.844231   -14.637559
# 25%       1.589922   -11.581520     0.058247     2.550606    -8.120223
# 50%       6.525167    -5.305916     1.569968     6.493896    -6.289175
# 75%      14.964859    -1.153177     3.861871     9.838585    -2.288359
# max      17.749851     3.570765    17.066487    16.178942     7.912809
#
#                 X6           X7           X8           X9          X10  \
# count  3960.000000  3960.000000  3960.000000  3960.000000  3960.000000
# mean      9.404835    -9.272039     4.845774    -0.620685    -3.331677
# std       5.002050     3.438432     2.739237     2.925264     3.744268
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(data = train_df.corr())

# %%
train_df.hist(figsize=(6,6), bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9c29a5a990>,
# ...
#       dtype=object)

# %%
train_df.boxplot()

# %%
train_df['language'].value_counts().plot.bar()
plt.tight_layout
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
train_df['language'].value_counts()
# Out:
# US    1933
# UK     647
# GE     414
# ES     339
# IT     327
# FR     300
# Name: language, dtype: int64

# %%
sns.countplot(data=train_df, x = 'language')

# %%
train_df['language'].value_counts().plot.pie(autopct = '%1.1f%%', labels = None, legend= True)

# %%
train_df.plot()

# %%
sns.pairplot(train_df, hue= 'language', markers = '+')
